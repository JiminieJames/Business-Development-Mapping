# %%
api_token = sk.eyJ1IjoiamJyYW5uYW4xIiwiYSI6ImNsemtsbzdyYjBjZDcybG9yZzRhbnB5b3UifQ.t5bobvh64NeeZmkMKLLAQA
public_token = pk.eyJ1IjoiamJyYW5uYW4xIiwiYSI6ImNsemtsajdxMjA3NnQybG9mZjJiMGIzeXMifQ.sasN30Hi5rI_sXNpqVqYsw

# %%
pip install mapbox==0.3.1
# Out:
# ...
#    ---------------------------------------- 0.0/139.2 kB ? eta -:--:--
#    ---------------------------------------- 139.2/139.2 kB 4.0 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/12.5 MB ? eta -:--:--
#    - -------------------------------------- 0.4/12.5 MB 8.7 MB/s eta 0:00:02
#    --- ------------------------------------ 1.0/12.5 MB 10.2 MB/s eta 0:00:02
#    ---- ----------------------------------- 1.5/12.5 MB 10.7 MB/s eta 0:00:02
#    ------ --------------------------------- 2.0/12.5 MB 11.7 MB/s eta 0:00:01
#    -------- ------------------------------- 2.6/12.5 MB 11.7 MB/s eta 0:00:01
#    ---------- ----------------------------- 3.1/12.5 MB 11.1 MB/s eta 0:00:01
#    ----------- ---------------------------- 3.7/12.5 MB 11.2 MB/s eta 0:00:01
#    ------------- -------------------------- 4.2/12.5 MB 11.7 MB/s eta 0:00:01
#    --------------- ------------------------ 4.8/12.5 MB 11.7 MB/s eta 0:00:01
# ...

# %%
import mapbox
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 import mapbox
#       3 geocoder - mapbox.Geocoder(access_token=api_token)
#
# File c:\Users\James\anaconda3\envs\dev\lib\site-packages\mapbox\__init__.py:5
#       2 __version__ = "0.3.1"
#       4 from .services.base import Service
# ----> 5 from .services.directions import Directions
#       6 from .services.distance import Distance
#       7 from .services.geocoding import Geocoder, InvalidPlaceTypeError
#
# File c:\Users\James\anaconda3\envs\dev\lib\site-packages\mapbox\services\directions.py:4
#       1 from uritemplate import URITemplate
#       3 from mapbox.services.base import Service
# ----> 4 from mapbox.encoding import encode_waypoints
#       7 class Directions(Service):
#       9     def __init__(self, access_token=None):
#
# ...

# %%
import re, requests, json

url = 'https://dfssdifhsid.com/themes/3/58597f55b92871671e000000/0/attachments/14822603711537993218/default/mapscript.js'

r = requests.get(url).content

# %%
# Base URL for the API

import re, requests, json

url = "https://api.mapbox.com/v4/mapbox.mapbox-streets-v8.json?secure&access_token=pk.eyJ1IjoiamJyYW5uYW4xIiwiYSI6ImNsemtsajdxMjA3NnQybG9mZjJiMGIzeXMifQ.sasN30Hi5rI_sXNpqVqYsw"

r = requests.get(url)

# %%
r
# Out:
# <Response [200]>

# %%
r.json()
# Out:
# {'attribution': '<a href="https://www.mapbox.com/about/maps/" target="_blank" title="Mapbox" aria-label="Mapbox">&copy; Mapbox</a> <a href="https://www.openstreetmap.org/about/" target="_blank" title="OpenStreetMap" aria-label="OpenStreetMap">&copy; OpenStreetMap</a> <a class="mapbox-improve-map" href="https://www.mapbox.com/contribute/" target="_blank" title="Improve this map" aria-label="Improve this map">Improve this map</a>',
#  'bounds': [-180, -85, 180, 85],
#  'center': [0, 0, 0],
#  'created': 1527888859555,
#  'filesize': 0,
#  'fillzoom': 8,
#  'format': 'pbf',
#  'id': 'mapbox.mapbox-streets-v8',
#  'language_options': {'ar': 'Arabic',
#   'ca': 'Catalan',
#   'cs': 'Czech',
#   'da': 'Danish',
#   'de': 'German',
#   'el': 'Greek',
#   'en': 'English',
#   'es': 'Spanish',
#   'fa': 'Farsi',
#   'fi': 'Finnish',
#   'fr': 'French',
#   'he': 'Hebrew',
#   'hu': 'Hungarian',
#   'id': 'Indonesian',
#   'it': 'Italian',
#   'ja': 'Japanese',
#   'ka': 'Georgian',
# ...
